# %% [markdown]
# <a href="https://colab.research.google.com/github/coding-cat23/data_mastery_showcase/blob/main/physical_activity_classifier/physical_activity_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
